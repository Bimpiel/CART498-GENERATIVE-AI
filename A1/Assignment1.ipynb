# %% [markdown]
# <a href="https://colab.research.google.com/github/Bimpiel/CART498-GENERATIVE-AI/blob/main/A1/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade diffusers transformers scipy

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load the model
model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)

# Define the prompts and number of images per prompt
prompts = [
    "What do the stars look like from the sky? make it sureal collage juxtaposition",
    "A vibrant nebula floating in deep space make it sureal collage juxtaposition ",
    "A surreal view of galaxies colliding in space make it sureal collage juxtaposition"
]
num_images = 1

# Generate images for each prompt
for prompt_idx, prompt in enumerate(prompts, 1):
    images = pipe(prompt, num_images_per_prompt=num_images).images
    for i, image in enumerate(images):
        image.save(f"Prompt_{prompt_idx}_Image_{i+1}.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
